# %%
# this code gives values of a, b such that a is minimum 
# we see that a as 1 always seems to satisfy our conditiom
# we find values of b for which a=1
# 
m = 30

def coprime(a, b):       
    return gcd(a, b) == 1         

def chkcop(vt):
    ga = 0
    la = len(vt)
    for xa in range(la):
        for ya in range(la):
            if xa != ya:
                #add "and xa > ya' to see pairs
                ma = vt[xa]
                na = vt[ya]
                if coprime(ma, na) == False:
                    ga += 1
                    break
            if ga > 0:
                break
        if ga > 0:
            break
    return ga == 0



for n in range(m):
    
    x = 0
    y = 0
    c = 0
    while c == 0:
        x += 1
        while c == 0:
            y += 1
            perro = []
            for m in range(n):
                g = x + m*y
                perro.append(g) 
            if chkcop(perro) == True:
                c += 1
                print(n,x,y)

# %%
# use this to limit^ a,b
lima = 100
limb = 100
# enter n to find values of a,b that are less than their limit^ (and satisfy our condition)
n = 8

def coprime(ya, yb):       
    return gcd(ya, yb) == 1         

def chkcop(vt):
    ga = 0
    la = len(vt)
    for xa in range(la):
        for ya in range(la):
            if xa != ya:
                #add "and xa > ya' to see pairs
                ma = vt[xa]
                na = vt[ya]
                if coprime(ma, na) == False:
                    ga += 1
                    break
            if ga > 0:
                break
        if ga > 0:
            break
    return ga == 0


for x in range(lima):
    for y in range(limb):
        y += 1
        perro = []
        for m in range(n):
            g = x + m*y
            perro.append(g) 
        if chkcop(perro) == True:
            print(x,y)
# Out:
# 1 6
# 1 18
# 1 30
# 1 36
# 1 48
# 1 60
# 1 66
# 1 78
# 1 90
# 1 96
# 11 6
# 11 18
# 11 30
# 11 36
# 11 48
# 11 60
# 11 78
# 11 90
# 11 96
# 13 18
# 13 24
# 13 30
# 13 48
# 13 54
# 13 60
# 13 84
# 13 90
# 17 6
# 17 12
# 17 30
# 17 36
# 17 42
# 17 60
# 17 66
# 17 72
# 17 90
# 17 96
# 19 12
# 19 24
# 19 30
# 19 42
# 19 54
# 19 60
# 19 72
# 19 84
# 19 90
# 23 18
# 23 24
# 23 30
# 23 48
# 23 54
# 23 60
# 23 78
# 23 84
# 23 90
# 29 12
# 29 24
# 29 30
# 29 42
# 29 54
# 29 60
# 29 72
# 29 84
# 29 90
# 31 6
# 31 18
# 31 30
# 31 36
# 31 48
# 31 60
# 31 66
# 31 78
# 31 90
# 31 96
# 37 6
# 37 12
# 37 30
# 37 36
# 37 42
# 37 60
# 37 66
# 37 72
# 37 90
# 37 96
# 41 6
# 41 18
# 41 30
# 41 36
# 41 48
# 41 60
# 41 66
# 41 78
# 41 90
# 41 96
# 43 18
# 43 24
# 43 30
# 43 48
# 43 54
# 43 60
# 43 78
# 43 84
# 43 90
# 47 6
# 47 12
# 47 30
# 47 36
# 47 42
# 47 60
# 47 66
# 47 72
# 47 90
# 47 96
# 53 18
# 53 24
# 53 30
# 53 48
# 53 54
# 53 60
# 53 78
# 53 84
# 53 90
# 59 12
# 59 24
# 59 30
# 59 42
# 59 54
# ...

# %%
def computeGCD(x, y): 
  
    if x > y: 
        small = y 
    else: 
        small = x 
    for i in range(1, small+1): 
        if((x % i == 0) and (y % i == 0)): 
            gcd = i 
              
    return gcd 
def coprime(a, b):       
    return computeGCD(a, b) == 1 
        

def chkcop(vt):
    g = 0
    l = len(vt)
    for x in range(l):
        for y in range(l):
            if x != y and x > y:
                m = vt[x]
                n = vt[y]
                if coprime(m, n) == False:
                    g += 1
    return g == 0

vect = [1, 11, 21, 31, 41, 51, 61, 71, 81, 91, 101, 111, 121, 131, 141, 151, 161, 171, 181, 191, 201, 211, 221, 231, 241, 251, 261, 271, 281, 291, 301, 311, 321, 331, 341, 351, 361, 371, 381, 391, 401, 411, 421, 431, 441, 451, 461, 471, 481, 491, 501, 511, 521, 531, 541, 551, 561, 571, 581, 591, 601, 611, 621, 631, 641, 651, 661, 671, 681, 691, 701, 711, 721, 731, 741, 751, 761, 771, 781, 791, 801, 811, 821, 831, 841, 851, 861, 871, 881, 891, 901, 911, 921, 931, 941, 951, 961, 971, 981, 991]

chkcop(vect)

# %%
def coprime(a, b):       
    return gcd(a, b) == 1         

def chkcop(vt):
    ga = 0
    la = len(vt)
    for xa in range(la):
        for ya in range(la):
            if xa != ya:
                #add "and xa > ya' to see pairs
                ma = vt[xa]
                na = vt[ya]
                if coprime(ma, na) == False:
                    ga += 1
                    break
            if ga > 0:
                break
        if ga > 0:
            break
    return ga == 0

x = 0
y = 0
c = 0

while c == 0:
    x += 1
    while c == 0:
        y += 1
        perro = []
        for m in range(n):
            g = x + m*y
            perro.append(g) 
        if chkcop(perro) == True:
            c += 1
            print(x,y)
            break
# Out:
# 1 150150
